# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
u_old = 0
v_old = 0
a_old = 0
u = 1

tau = 1

# %%
# Newmark method
v = 2 / tau * (u - u_old) - v_old
print(v)
# Out:
# 2.0

# %%
a = 2/tau * (v - v_old) - a_old
print(a)
# Out:
# 4.0

# %%
u_values = [i for i in range(10)]
