# %% [markdown]
# # Co-Simulation Algorithms

# %% [markdown]
# ## Jacobi Algorithm

# %% [markdown]
# ## Gauss-Seidel Algorithm

# %% [markdown]
# ## Hybrid Alotithms

# %% [markdown]
# ## Comparison of Co-Simulation Algorithms
