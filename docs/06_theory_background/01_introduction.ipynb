# %% [markdown]
# # Introduction

# %% [markdown]
# ## Purpose and Scope of `syssimx`

# %% [markdown]
# ## Heterogeneous Co-Simulation Overview

# %% [markdown]
# ## Mental Model Summary

# %% [markdown]
# ## Link to Concepts and Quickstart
