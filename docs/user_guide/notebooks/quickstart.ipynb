# %% [markdown]
# # Quickstart Notebook
#
# This notebook mirrors the Quick Start guide and provides a runnable entry point.

# %%
import syssimx as sx

print(sx.__version__)

# %% [markdown]
# Next steps:
# - Walk through `docs/user_guide/quickstart.rst` for a full example.
# - Extend the system with components from `docs/user_guide/components.rst`.
