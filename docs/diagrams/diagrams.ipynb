# %%
import sys
import os
import subprocess
import pathlib
from pathlib import Path
from IPython.display import SVG, display

src_dir = Path.cwd() / 'src'
src_files = list(src_dir.rglob('*.puml'))

for i, puml_file in enumerate(src_files):
    print(f'Processing file {i + 1}/{len(src_files)}: {puml_file}')
    outdir = Path.cwd() / 'out'
    output_file = outdir / puml_file.with_suffix('.svg').name
    subprocess.run(['plantuml', '-tsvg', str(puml_file), '-o', str(outdir)], check=True)
# Out:
# Processing file 1/23: /home/flo/code/SystemSimulation/docs/diagrams/src/class/system/system_graph_viz.puml
# Processing file 2/23: /home/flo/code/SystemSimulation/docs/diagrams/src/class/system/system.puml
# Processing file 3/23: /home/flo/code/SystemSimulation/docs/diagrams/src/class/core/base.puml
# Processing file 4/23: /home/flo/code/SystemSimulation/docs/diagrams/src/class/core/portsystem.puml
# Processing file 5/23: /home/flo/code/SystemSimulation/docs/diagrams/src/class/core/port.puml
# Processing file 6/23: /home/flo/code/SystemSimulation/docs/diagrams/src/class/components/multi_comp.puml
# Processing file 7/23: /home/flo/code/SystemSimulation/docs/diagrams/src/class/components/opensim_comp.puml
# Processing file 8/23: /home/flo/code/SystemSimulation/docs/diagrams/src/class/components/fmu_comp.puml
# Processing file 9/23: /home/flo/code/SystemSimulation/docs/diagrams/src/class/models/fem_pendulum.puml
# Processing file 10/23: /home/flo/code/SystemSimulation/docs/diagrams/src/class/models/multi_pendulum.puml
# Processing file 11/23: /home/flo/code/SystemSimulation/docs/diagrams/src/class/models/opensim_pendulum.puml
# Processing file 12/23: /home/flo/code/SystemSimulation/docs/diagrams/src/execution/global_ijcsa.puml
# Processing file 13/23: /home/flo/code/SystemSimulation/docs/diagrams/src/execution/SwitchingDiagram.puml
# Processing file 14/23: /home/flo/code/SystemSimulation/docs/diagrams/src/execution/local_ijcsa.puml
# Processing file 15/23: /home/flo/code/SystemSimulation/docs/diagrams/src/execution/jacobi.puml
# Processing file 16/23: /home/flo/code/SystemSimulation/docs/diagrams/src/execution/gauss_seidel.puml
# Processing file 17/23: /home/flo/code/SystemSimulation/docs/diagrams/src/execution/ExecutionDiagram.puml
# Processing file 18/23: /home/flo/code/SystemSimulation/docs/diagrams/src/execution/theory/gauss_seidel_theory.puml
# Processing file 19/23: /home/flo/code/SystemSimulation/docs/diagrams/src/execution/theory/ijcsa_theory.puml
# Processing file 20/23: /home/flo/code/SystemSimulation/docs/diagrams/src/execution/theory/jacobi_theory.puml
# Processing file 21/23: /home/flo/code/SystemSimulation/docs/diagrams/src/architecture/SysSimX_Framework.puml
# Processing file 22/23: /home/flo/code/SystemSimulation/docs/diagrams/src/architecture/LayerDiagram.puml
# Processing file 23/23: /home/flo/code/SystemSimulation/docs/diagrams/src/architecture/SysSimX_Simplified.puml
