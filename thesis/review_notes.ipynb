# %% [markdown]
# # Review Notes: Development of a Framework for System Simulation
#
# ---

# %% [markdown]
# ## Others
#
# To Do:
# - Abstract
# - Acknowledgements
# - Acronyms
# - Kurzfassung
#
# ---

# %% [markdown]
# Repeated introduction and explanation of concepts
# - At different level of detail and in slightly different context:
#     - FMI / FMU concept
#     - Monolithic Simulation
#     - Co-Simulation
#     - Musculoskeletal Modeling
#     - Finite Element Analysis
# - Focus that early chapters and sections stay on high-level concepts while later sections can state that the concept is already introduced and state then only new concepts and technical details needed

# %% [markdown]
# General FEM vs. Continuum Mechanics
#
# - Introduction / Motivation states FEA/FEM directly while the theoretical background chapter introduces continuum mechanics
# - Idea: Introduce FEM compact and shortly in general and then introduce continuum mechanics as classical application for FEM
