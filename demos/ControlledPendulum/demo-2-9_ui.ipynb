# %%
import sys
from pathlib import Path
import importlib

sys.path.append(str(Path.cwd().parent.parent))

import SysSimX
importlib.reload(SysSimX)

from SysSimX.ui.ui_manager import step1_ui, demo_ui
from SysSimX.ui.ui_core import ui

#UIManager = step1_ui()

# %%
my_ui = ui
display(my_ui)

# %%
from SysSimX.ui.app import UiApp
from SysSimX.ui.state import AppState

state = AppState()
app = UiApp(state)
display(app)
# Out:
# UiApp(children=(HTML(value='<h2>SysSimX — Simulation Workflow</h2>'), Accordion(children=(ModelSelectionView(c…
